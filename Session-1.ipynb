# %% [markdown]
# 1.Python Output

# %%
print("Welcome to python")
# Out:
# Welcome to python

# %%
print(Welcome to Bikkad IT)
# Out:
#   Cell In[2], line 1
#     print(Welcome to Bikkad IT)
#           ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %%
print ("wellcome to data engineer ")
# Out:
# wellcome to data engineer

# %%
Print ("wellcome to python ")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 Print ("wellcome to python ")
#
# NameError: name 'Print' is not defined

# %%
print("wellcome to python ")
# Out:
# wellcome to python

# %%
print (100)
# Out:
# 100

# %%
print(3.14)
# Out:
# 3.14

# %%
print("name","pratik","age",23)
# Out:
# name pratik age 23

# %%
print (10,20,30,40)
# Out:
# 10 20 30 40

# %%
print("pratik","chetan","sohan")
# Out:
# pratik chetan sohan

# %%
print("Apple",end=" ")
print("Banana")
# Out:
# Apple Banana

# %%
print("sohan")
print()
print("chetan")
# Out:
# sohan
#
# chetan

# %% [markdown]
# # 2. Python Data Types

# %%
# integer - Whole Number - Example 10, -5, 0
# Float   - Decimal Number - Example 3.14,-2.5,0.0
# String  - Text           - Example "Hello",'python'
# Boolean - True or False  - Example True, False

# %%
# Integer - int

a = 10
b = -5
c = 0

# %%
print(a)
# Out:
# 10

# %%
print(type(a))
# Out:
# <class 'int'>

# %%
print(type(b))
# Out:
# <class 'int'>

# %%
x = 10.5
y = -3.14
z = 0.0

# %%
print(x, type(x))
print(y, type(y))
print(z, type(z))
# Out:
# 10.5 <class 'float'>
# -3.14 <class 'float'>
# 0.0 <class 'float'>

# %%
name = "Python"
Greeting = 'Hello'

# %%
print(name, type(name))
print(Greeting, type(Greeting))
# Out:
# Python <class 'str'>
# Hello <class 'str'>

# %%
Flag_True =True
Flag_False = False

# %%
print(Flag_True, type(Flag_True))
print(Flag_False, type(Flag_False))
# Out:
# True <class 'bool'>
# False <class 'bool'>

# %% [markdown]
# # 3.Variables

# %%
# Valid Variable
name = "sohan"
_age = 23
Student1 = "chetan"
total_marks = 400

# %%
1student = "kiran"
# Out:
#   Cell In[31], line 1
#     1student = "kiran"
#     ^
# SyntaxError: invalid decimal literal

# %%
my-name = "atish"
# Out:
#   Cell In[32], line 1
#     my-name = "atish"
#     ^
# SyntaxError: cannot assign to expression here. Maybe you meant '==' instead of '='?

# %%
class = abc
# Out:
#   Cell In[33], line 1
#     class = abc
#           ^
# SyntaxError: invalid syntax

# %%
# Basic Variable

name = "Sneha"
age = 22
height = 5.4
is_Student = True

# %%
# Multiple Assignment

x = y = z = 100
print(x,y,z)
# Out:
# 100 100 100

# %%
# Assign Different Value

a,b,c = 10,20,30
print(a,b,c)
# Out:
# 10 20 30

# %%
marks = 85
print(marks)
# Out:
# 85

# %%
marks = 90
print(marks)
# Out:
# 90

# %%
print(marks)
# Out:
# 90

# %% [markdown]
# # 4. Comments

# %% [markdown]
#  # 1.Single line Comment

# %%
print("Hello") # this is single line comment
# Out:
# Hello

# %% [markdown]
# # 2.Multi Line Comment

# %%
''' This is first Line
This is Second Line
This is Third Line 
'''
print("Python")
# Out:
# Python

# %% [markdown]
# # 5. Keywords

# %%
name = "pratik"

# %%
print(name)
# Out:
# pratik

# %%
import keyword

# %%
Keywords = keyword.kwlist

# %%
print(Keywords)
# Out:
# ['False', 'None', 'True', 'and', 'as', 'assert', 'async', 'await', 'break', 'class', 'continue', 'def', 'del', 'elif', 'else', 'except', 'finally', 'for', 'from', 'global', 'if', 'import', 'in', 'is', 'lambda', 'nonlocal', 'not', 'or', 'pass', 'raise', 'return', 'try', 'while', 'with', 'yield']

# %%
False = "pratik"
# Out:
#   Cell In[56], line 1
#     False = "pratik"
#     ^
# SyntaxError: cannot assign to False

# %% [markdown]
# #  6.User Input

# %% [markdown]
# #  7. Type Conversion / Type Casting

# %%
# Example : Basic Input

name = input("Enter your name : ")
# Out:
# Enter your name :  pratik

# %%
age = input("Enter your age : ")
# Out:
# Enter your age :  22

# %%
print(age)
# Out:
# 22

# %%
print(type(age))
# Out:
# <class 'str'>

# %%
age + 3
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 age + 3
#
# TypeError: can only concatenate str (not "int") to str

# %% [markdown]
# # a) implicit Conversion

# %%
a = 10
b = 3.5
c = a + b

# %%
print(a, type(a))
print(b, type(b))
print(c, type(c))
# Out:
# 10 <class 'int'>
# 3.5 <class 'float'>
# 13.5 <class 'float'>

# %% [markdown]
# # b) Explicit Conversion

# %%
#  string to Integer
x = "100"
y = int(x)
print(y+50)
# Out:
# 150

# %%
print(x, type(x))
print(y,type(y))
# Out:
# 100 <class 'str'>
# 100 <class 'int'>

# %%
x = "150"
y = 50
print(x+y)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 3
#       1 x = "150"
#       2 y = 50
# ----> 3 print(x+y)
#
# TypeError: can only concatenate str (not "int") to str

# %%
# integer to Float

a = 27
b = float(a)
print(b)
# Out:
# 27.0

# %%
# float to integer
c = 4.05
d = int(c)
print(d)
# Out:
# 4

# %%
# Number to string
age = 25
age_str = str(age)
print("Age :" + age_str)
# Out:
# Age :25

# %%
age = 35
age_str = "35"
print(age + age_str)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[11], line 3
#       1 age = 35
#       2 age_str = "35"
# ----> 3 print(age + age_str)
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %% [markdown]
# # 8. Escape Sequence

# %%
text1 = "Hello\nPRATIK"  # New Line Character

# %%
print(text1)
# Out:
# Hello
# PRATIK

# %%
Text2 = "Name:\tBROTHER"  # Tab
print(Text2)
# Out:
# Name:	BROTHER
